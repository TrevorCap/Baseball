# %%
#Importing of dependencies, maybe don't need all?
import matplotlib.pyplot as plt
import csv
import numpy as np
from numpy.polynomial.polynomial import polyfit as poly
import statsmodels.api as sm
import scipy as stats
import pandas as pd
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics as mt

# %%
milb2019 = pd.read_csv("Resources/2019_milb_data.csv")

# %%
milb2019.head(5)
# Out:
#      hc_x    hc_y next_event_type event_and_next_event_type  \
# 0  143.47  176.86       field_out                 field_out
# 1   74.36   96.92          single                    single
# 2  198.40  130.50       field_out                 field_out
# 3  129.21  190.65       field_out                 field_out
# 4  108.64  157.51       field_out                 field_out
#
#                                    event_description    batter_name  \
# 0  Gavin Lux grounds out to first baseman Chris C...      Gavin Lux
# 1  Richy Pedroza singles on a line drive to left ...  Richy Pedroza
# 2  Marcus Chiu flies out to right fielder Luis Al...    Marcus Chiu
# 3  Luken Baker grounds out softly, catcher Brady ...    Luken Baker
# 4  Jeter Downs grounds out, shortstop Jancarlos C...    Jeter Downs
#
#         pitcher_name  outs  balls  strikes  ... is_hit_into_play  \
# 0       Johan Oviedo     0    0.0      1.0  ...                1
# ...

# %%
# HRs = milb2019[milb2019.next_event_type == "home_run"]
# tBs = milb2019[milb2019.next_event_type == "triple"]
# dBs = milb2019[milb2019.next_event_type == "double"]
# sBs = milb2019[milb2019.next_event_type == "single"]
# Os = milb2019[milb2019.next_event_type == "field_out"]

# %%
# plt.scatter(HRs.hc_x, HRs.hc_y, color='green')
# plt.scatter(tBs.hc_x, tBs.hc_y, color='orange')
# plt.scatter(dBs.hc_x, dBs.hc_y, color='yellow')
# plt.scatter(sBs.hc_x, sBs.hc_y, color='red')

# %%
# outcome = milb2019.event_and_next_event_type
# process = milb2019[['hc_x', 'hc_y', 'hit_trajectory']]
# outcome = outcome.replace(['catcher_interf', 'double', 'double_play', 'field_error', 'field_out', 'fielders_choice', 'fielders_choice_out', 'force_out', 'grounded_into_double_play', 'hit_by_pitch', 'home_run', 'intent_walk', 'sac_bunt', 'sac_bunt_double_play', 'sac_fly', 'sac_fly_double_play', 'single', 'stolen_base_2b', 'strikeout', 'strikeout_double_play', 'triple', 'triple_play', 'walk'],
#                          [0, 8, -5, 5, -2, 4, 3, -1, -2, 0, 10, 0, -1, -2, 1, 2, 7, 0, 0, 0, 9, -2, 0])
# process = process.replace(['ground_ball', 'line_drive', 'fly_ball', 'popup'], [-1, 0, 1, 2])
# process = process.fillna(-5)

# %%
# omodel = RandomForestRegressor()
# omodel.fit(process, outcome)
# ohat = omodel.predict(process)
# oscore = omodel.score(process, outcome)
# Out:
# C:\Users\Trevor\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
milb2019 = milb2019[milb2019['hc_x'] != 'NaN']
milb2019.head()
# Out:
#      hc_x    hc_y next_event_type event_and_next_event_type  \
# 0  143.47  176.86       field_out                 field_out
# 1   74.36   96.92          single                    single
# 2  198.40  130.50       field_out                 field_out
# 3  129.21  190.65       field_out                 field_out
# 4  108.64  157.51       field_out                 field_out
#
#                                    event_description    batter_name  \
# 0  Gavin Lux grounds out to first baseman Chris C...      Gavin Lux
# 1  Richy Pedroza singles on a line drive to left ...  Richy Pedroza
# 2  Marcus Chiu flies out to right fielder Luis Al...    Marcus Chiu
# 3  Luken Baker grounds out softly, catcher Brady ...    Luken Baker
# 4  Jeter Downs grounds out, shortstop Jancarlos C...    Jeter Downs
#
#         pitcher_name  outs  balls  strikes  ... is_hit_into_play_basehit  \
# 0       Johan Oviedo     0    0.0      1.0  ...                        0
# ...

# %%
milb2019['fbdist'] = 2.29 * np.sqrt((milb2019.hc_x-126)*(milb2019.hc_x-126) + (204-milb2019.hc_y)*(204-milb2019.hc_y))

# %%
milb2019.head(8)
# Out:
#      hc_x    hc_y next_event_type event_and_next_event_type  \
# 0  143.47  176.86       field_out                 field_out
# 1   74.36   96.92          single                    single
# 2  198.40  130.50       field_out                 field_out
# 3  129.21  190.65       field_out                 field_out
# 4  108.64  157.51       field_out                 field_out
# 5  105.34  170.79       field_out                 field_out
# 6  108.69  156.80       field_out                 field_out
# 7     NaN     NaN             NaN                 strikeout
#
#                                    event_description    batter_name  \
# 0  Gavin Lux grounds out to first baseman Chris C...      Gavin Lux
# 1  Richy Pedroza singles on a line drive to left ...  Richy Pedroza
# 2  Marcus Chiu flies out to right fielder Luis Al...    Marcus Chiu
# 3  Luken Baker grounds out softly, catcher Brady ...    Luken Baker
# 4  Jeter Downs grounds out, shortstop Jancarlos C...    Jeter Downs
# ...

# %%
FB = milb2019[milb2019['hit_trajectory'] == 'fly_ball']
grouped = FB.groupby('batter_name').mean()

# %%
grouped.sort_values(by='fbdist', ascending=False).head(25)
# Out:
#                         hc_x       hc_y      outs     balls   strikes  \
# batter_name
# Adrian Houser      171.28000  22.310000  1.000000  0.000000  1.000000
# Giancarlo Stanton  126.50000  18.870000  2.000000  2.000000  1.000000
# Michael Cantu      139.71000  27.865000  1.000000  1.500000  1.000000
# Ryan Castellani    196.64000  41.790000  2.000000  0.000000  0.000000
# Adam Moore         197.82000  43.120000  2.000000  0.000000  0.000000
# Jairo Perez         10.89000  73.710000  2.000000  1.000000  0.000000
# Brandon Gold        77.43000  37.140000  0.000000  2.000000  1.000000
# Rougned Odor       142.86000  31.195000  1.000000  1.000000  0.500000
# Dashenko Ricardo    73.94000  40.560000  1.000000  0.000000  2.000000
# Garrett Hampson     54.30000  50.270000  2.000000  3.000000  2.000000
# Kyle McGowin       134.86500  40.280000  1.500000  1.500000  1.500000
# Chandler Taylor    194.31000  59.263333  0.666667  1.666667  1.333333
# ...
